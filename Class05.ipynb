# %% [markdown]
# #Discrete Convolution
#
# It's a fundamental operation in signal processing, used to combine 2 discrete signals.
# Convolution is a mathematical way to combining 2 signals to form a third one, representing how the shape of one is modified by the other.

# %%
import numpy as np
from matplotlib import pyplot as plt

# Setting the figure size
plt.rcParams['figure.figsize'] = [12, 5]

# %%
# Defining our signals
firstSignal = [2, 2, -1]
secondSignal = [4, 3, 2, 1]

# Define the sample indices for the input signals
indexFirstSampleFirstSignal = 0
indexLastSampleFirstSignal = 2

indexFirstSampleSecondSignal = 0
indexLastSampleSecondSignal = 3

# Convolution
convolution = np.convolve(secondSignal, firstSignal)

# Create arrays of sample indices for the input signals
firstSignalIndices = np.arange(indexFirstSampleFirstSignal, indexLastSampleFirstSignal + 1)
secondSignalIndices = np.arange(indexFirstSampleSecondSignal, indexLastSampleSecondSignal + 1)

# Calculate the output indices
# The number of output samples = M + N - 1, where M and N are the lengths of firstSignal and secondSignal respectively
outputIndices = np.arange(min(firstSignalIndices) + min(secondSignalIndices), max(firstSignalIndices) + max(secondSignalIndices) + 1)

# %% [markdown]
# #Length of the Convolution Result
#
# When you convolve two discrete signals
# 𝑥
# [
# 𝑛
# ]
# x[n] and
# ℎ
# [
# 𝑛
# ]
# h[n] of lengths
# 𝑀
# M and
# 𝑁
# N respectively, the resulting signal
# 𝑦
# [
# 𝑛
# ]
# y[n] has a length of
# **M+N−1**. This is because each element in
# 𝑦
# [
# 𝑛
# ]
# y[n] is the sum of products of overlapping elements from
# 𝑥
# [
# 𝑛
# ]
# x[n] and
# ℎ
# [
# 𝑛
# ]
# h[n] as they are slid across each other.

# %%
# Plotting the result
plt.grid("on")
plt.title("Convolution Result")
plt.xlabel("Sample (n)")
plt.ylabel("Amplitude")
plt.stem(outputIndices, convolution, use_line_collection=True)
plt.axvline(0, color='r')
plt.axhline(0, color='r')
plt.show()
# Out:
# <ipython-input-23-d248a166b401>:6: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(outputIndices, convolution, use_line_collection=True)

# %% [markdown]
# #Exercise 2:

# %%
# Defining our signals
firstSignal2 = [2, 0, 3, 0, 2]
secondSignal2 = [5,-1, -2, 3]

# Define the sample indices for the input signals
indexFirstSampleFirstSignal2 = -2
indexLastSampleFirstSignal2 = 2

indexFirstSampleSecondSignal2 = 0
indexLastSampleSecondSignal2 = 3

# Convolution
convolution2 = np.convolve(secondSignal2, firstSignal2)

# Create arrays of sample indices for the input signals
firstSignalIndices2 = np.arange(indexFirstSampleFirstSignal2, indexLastSampleFirstSignal2 + 1)
secondSignalIndices2 = np.arange(indexFirstSampleSecondSignal2, indexLastSampleSecondSignal2 + 1)

# Calculate the output indices
# The number of output samples = M + N - 1, where M and N are the lengths of firstSignal and secondSignal respectively
outputIndices2 = np.arange(min(firstSignalIndices2) + min(secondSignalIndices2), max(firstSignalIndices2) + max(secondSignalIndices2) + 1)

# %%
# Plotting the result
plt.grid("on")
plt.title("Convolution Result")
plt.xlabel("Sample (n)")
plt.ylabel("Amplitude")
plt.stem(outputIndices2, convolution2, use_line_collection=True)
plt.axvline(0, color='r')
plt.axhline(0, color='r')
plt.show()
# Out:
# <ipython-input-25-98b2a80090f7>:6: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(outputIndices2, convolution2, use_line_collection=True)
